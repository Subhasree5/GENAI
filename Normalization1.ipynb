# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
text = "NLTK is AMAZING! It helps normalize texts, removing punctuation and stopwords easily."

# %%
text = text.lower()
print(text)
# Out:
# nltk is amazing! it helps normalize texts, removing punctuation and stopwords easily.

# %%
from nltk.tokenize import word_tokenize

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['nltk', 'is', 'amazing', '!', 'it', 'helps', 'normalize', 'texts', ',', 'removing', 'punctuation', 'and', 'stopwords', 'easily', '.']

# %%
import string

tokens_no_punct = [word for word in tokens if word not in string.punctuation]
print(tokens_no_punct)
# Out:
# ['nltk', 'is', 'amazing', 'it', 'helps', 'normalize', 'texts', 'removing', 'punctuation', 'and', 'stopwords', 'easily']

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

tokens_no_stopwords = [word for word in tokens_no_punct if word not in stop_words]
print(tokens_no_stopwords)
# Out:
# ['nltk', 'amazing', 'helps', 'normalize', 'texts', 'removing', 'punctuation', 'stopwords', 'easily']

# %%
import re
text = "NLTK is AMAZING!!! Version 3.8 😊"

clean_text = re.sub(r'[^a-zA-Z\s]', '', text)
print(clean_text)
# Out:
# NLTK is AMAZING Version

# %%
clean_text = clean_text.lower()
print(clean_text)
# Out:
# nltk is amazing version

# %%
text = "I have 2 dogs and 3 cats"
clean_text = re.sub(r'\d+', '', text)
print(clean_text)
# Out:
# I have  dogs and  cats

# %%
text = "This    sentence   has   extra spaces"
clean_text = re.sub(r'\s+', ' ', text).strip()
print(clean_text)
# Out:
# This sentence has extra spaces

# %%
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def normalize_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  # remove punctuation & numbers
    tokens = word_tokenize(text)
    tokens = [w for w in tokens if w not in stop_words]
    tokens = [lemmatizer.lemmatize(w) for w in tokens]
    return tokens
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
normalize_text("Normalization in NLTK is AWESOME!!! Version 3.8 😎")
# Out:
# ['normalization', 'nltk', 'awesome', 'version']

# %%
import re
from nltk.tokenize import word_tokenize

text = "The children are running and studies are completed!!!"
text = text.lower()
text = re.sub(r'[^a-z\s]', '', text)

tokens = word_tokenize(text)
print(tokens)
# Out:
# ['the', 'children', 'are', 'running', 'and', 'studies', 'are', 'completed']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
stemmed = [stemmer.stem(word) for word in tokens]
print(stemmed)
# Out:
# ['the', 'children', 'are', 'run', 'and', 'studi', 'are', 'complet']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
lemmatized = [lemmatizer.lemmatize(word) for word in tokens]
print(lemmatized)
# Out:
# ['the', 'child', 'are', 'running', 'and', 'study', 'are', 'completed']
